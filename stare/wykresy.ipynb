# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
pd.options.mode.chained_assignment = None 
# test

# %%
Bs= [60, 75, 90, 105, 120] 
t_ks =[30,40,50,60,70,80,90]
modes = ["PT","Car"]
aggs = ['mean','min','max','std','median', 'p_25', 'p_75']

# %%
def readone(ch,B,t_k,mode, agg, folder = 'data//res//'):
    name = "{}_{}_{}_{}".format(ch,mode,str(B),str(t_k))
    path = folder+'A_i_'+name+".csv"  
    df = pd.read_csv(path, index_col=0)
    return df['A_i_'+name+agg]

# %%
B_plot = pd.DataFrame(index = Bs)
t_plot =  pd.DataFrame(index = t_ks)

# %%
xs = [readone("C",B,30,"PT",'mean').loc[230] for B in Bs]
B_plot['230']=xs

# %%
B_plot.plot()

# %%
B_plot.plot(kind='bar')

# %%
ts = [readone("C",120,t,"PT",'mean').loc[130] for t in t_ks]
t_plot['230']=ts
t_plot.plot(kind='bar')
