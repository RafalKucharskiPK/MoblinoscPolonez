# %%
import pandas as pd

# %%
path = "bibycle_miltichannel_queue.csv"

# %%
df = pd.read_csv(path, header=1, sep=";")

# %%
df.columns
# Out:
# Index(['Q', 'c', 'ta', 'xs', 'n', 'p', 'ts', 'te'], dtype='object')

# %%
d = dict()
for col in df.columns:
    d[col]=float

# %%
df.groupby('Q')['ts'].mean().plot()
